# %% [markdown]
# <a href="https://colab.research.google.com/github/meriemdouider1/MOIS-8-2022/blob/main/DFS_MCC_CS_LONGIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import roc_auc_score, r2_score
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import numpy
import sklearn.metrics as metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
import numpy as np
from sklearn import svm, datasets
from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
from sklearn.metrics import matthews_corrcoef
from sklearn.svm import SVC
from sklearn.metrics import cohen_kappa_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import RFE
from sklearn.pipeline import Pipeline
from matplotlib import pyplot

# %%
Cl1 = '/content/cs-longia.xlsx' 
data=pd.read_excel(Cl1, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
data
# Out:
#      Cs_longia     X_long      Y_lat    Bovins    Volaille   Caprins  \
# 0            1 -15.911420  23.794740  0.000000    0.000000  0.000000
# 1            1 -13.188370  27.132950  0.000214    0.000000  0.063449
# 2            1 -13.188370  27.132950  0.000214    0.000000  0.063449
# 3            0 -13.185620  27.157940  0.000000    0.000000  0.000000
# 4            0 -13.167180  27.157730  0.000000    0.000000  0.000000
# ..         ...        ...        ...       ...         ...       ...
# 249          1  -5.366667  35.766667  8.495770  105.550156  8.691405
# 250          1  -5.816667  35.783333  0.000000    0.000000  0.000000
# 251          1  -5.366667  35.833333  7.411978  111.459663  7.364459
# 252          1  -5.558611  35.841944  5.696193    5.641273  0.602672
# 253          1  -5.483333  35.900000  6.839514   15.082421  0.782080
#
#          Ovins   Equides  Coniferes  ZoneAride  ...  Vent_Mars  Vent_Avril  \
# 0     0.000000  0.624435          0         97  ...        6.1         6.9
# 1     0.034352  0.040295          0        100  ...        4.8         5.6
# 2     0.034352  0.040295          0        100  ...        4.8         5.6
# 3     0.000000  0.269410          0        100  ...        5.1         5.6
# 4     0.000000  0.379107          0        100  ...        5.0         5.2
# ..         ...       ...        ...        ...  ...        ...         ...
# 249  15.116930  0.698221          0          0  ...        4.6         4.3
# 250   0.000000  1.725019          0          0  ...        4.6         4.1
# 251  15.054404  0.991284          0          0  ...        4.5         4.3
# 252   4.306276  0.000000          0          0  ...        4.6         4.0
# 253   6.042903  0.595441          0          0  ...        4.7         4.4
#
#      Vent_Mai  Vent_Juin  Vent_Juill  Vent_Aout  Vent_Sept  Vent_Oct  \
# 0         7.2        7.1         7.5        7.2        6.3       5.4
# 1         5.7        6.4         5.9        5.9        5.7       4.3
# 2         5.7        6.4         5.9        5.9        5.7       4.3
# 3         5.5        6.2         6.2        6.2        5.7       4.1
# 4         5.4        5.7         6.2        5.8        5.6       4.2
# ..        ...        ...         ...        ...        ...       ...
# 249       4.1        3.9         3.9        4.1        4.0       4.0
# 250       3.8        3.7         3.7        3.7        3.3       3.6
# 251       4.0        4.0         3.9        4.0        3.9       4.0
# 252       3.8        4.1         3.7        3.4        3.6       3.6
# 253       3.9        3.8         3.9        3.7        4.0       4.0
#
#      Vent_Nov  Vent_Dec
# 0         5.5       4.9
# 1         3.7       3.8
# 2         3.7       3.8
# 3         3.7       3.9
# 4         3.6       3.8
# ..        ...       ...
# 249       4.0       4.2
# 250       3.8       4.0
# 251       3.9       4.3
# 252       3.4       3.6
# 253       4.0       4.2
#
# [254 rows x 226 columns]

# %%
data["Cs_longia"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 249    1
# 250    1
# 251    1
# 252    1
# 253    1
# Name: Cs_longia, Length: 254, dtype: int64

# %%
X = data.loc[:, data.columns != 'Cs_longia']
y = data.Cs_longia

# %%
X
# Out:
#         X_long      Y_lat    Bovins    Volaille   Caprins      Ovins  \
# 0   -15.911420  23.794740  0.000000    0.000000  0.000000   0.000000
# 1   -13.188370  27.132950  0.000214    0.000000  0.063449   0.034352
# 2   -13.188370  27.132950  0.000214    0.000000  0.063449   0.034352
# 3   -13.185620  27.157940  0.000000    0.000000  0.000000   0.000000
# 4   -13.167180  27.157730  0.000000    0.000000  0.000000   0.000000
# ..         ...        ...       ...         ...       ...        ...
# 249  -5.366667  35.766667  8.495770  105.550156  8.691405  15.116930
# 250  -5.816667  35.783333  0.000000    0.000000  0.000000   0.000000
# 251  -5.366667  35.833333  7.411978  111.459663  7.364459  15.054404
# 252  -5.558611  35.841944  5.696193    5.641273  0.602672   4.306276
# 253  -5.483333  35.900000  6.839514   15.082421  0.782080   6.042903
#
#       Equides  Coniferes  ZoneAride  ZonePel  ...  Vent_Mars  Vent_Avril  \
# 0    0.624435          0         97        3  ...        6.1         6.9
# 1    0.040295          0        100        0  ...        4.8         5.6
# 2    0.040295          0        100        0  ...        4.8         5.6
# 3    0.269410          0        100        0  ...        5.1         5.6
# 4    0.379107          0        100        0  ...        5.0         5.2
# ..        ...        ...        ...      ...  ...        ...         ...
# 249  0.698221          0          0        0  ...        4.6         4.3
# 250  1.725019          0          0        0  ...        4.6         4.1
# 251  0.991284          0          0        0  ...        4.5         4.3
# 252  0.000000          0          0       58  ...        4.6         4.0
# 253  0.595441          0          0        5  ...        4.7         4.4
#
#      Vent_Mai  Vent_Juin  Vent_Juill  Vent_Aout  Vent_Sept  Vent_Oct  \
# 0         7.2        7.1         7.5        7.2        6.3       5.4
# 1         5.7        6.4         5.9        5.9        5.7       4.3
# 2         5.7        6.4         5.9        5.9        5.7       4.3
# 3         5.5        6.2         6.2        6.2        5.7       4.1
# 4         5.4        5.7         6.2        5.8        5.6       4.2
# ..        ...        ...         ...        ...        ...       ...
# 249       4.1        3.9         3.9        4.1        4.0       4.0
# 250       3.8        3.7         3.7        3.7        3.3       3.6
# 251       4.0        4.0         3.9        4.0        3.9       4.0
# 252       3.8        4.1         3.7        3.4        3.6       3.6
# 253       3.9        3.8         3.9        3.7        4.0       4.0
#
#      Vent_Nov  Vent_Dec
# 0         5.5       4.9
# 1         3.7       3.8
# 2         3.7       3.8
# 3         3.7       3.9
# 4         3.6       3.8
# ..        ...       ...
# 249       4.0       4.2
# 250       3.8       4.0
# 251       3.9       4.3
# 252       3.4       3.6
# 253       4.0       4.2
#
# [254 rows x 225 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 249    1
# 250    1
# 251    1
# 252    1
# 253    1
# Name: Cs_longia, Length: 254, dtype: int64

# %%
algo = GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1 )

# %% [markdown]
# # Test 0 : MODÈLE RFECV

# %%
f0= ['Min_IRM', 'Amp1_TempJ', 'Max_TempN', 'VarT_ann_NDVI', 'Var_EVI',
       'ProfAbs_Sub', 'IR_Moy', 'Rad_Mai', 'Tmax_Fev', 'Tmax_Avril']

# %%
def specificite(y_true, y_pred):
  specificite= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
  return specificite
my_scorer = make_scorer(specificite, greater_is_better=True)
def MCC(y_true, y_pred):
  MCC= matthews_corrcoef(y_true, y_pred) 
  return MCC
my_scorer1 = make_scorer(MCC, greater_is_better=True)
def présicion_positive(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[1,1])/(cf_matrix[1,1]+cf_matrix[0,1])
  return pre_pos
my_scorer2 = make_scorer(présicion_positive, greater_is_better=True)
def présicion_négative(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[0,0])/(cf_matrix[0,0]+cf_matrix[1,0])
  return pre_pos
my_scorer3 = make_scorer(présicion_négative, greater_is_better=True)
def VN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,0]
    return value
my_scorer4 = make_scorer(VN, greater_is_better=True)
def VP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,1]
    return value
my_scorer5 = make_scorer(VP, greater_is_better=True)
def FP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,1]
    return value
my_scorer6 = make_scorer(FP, greater_is_better=True)
def FN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,0]
    return value
my_scorer7 = make_scorer(FN, greater_is_better=True)

# %%
cv = KFold(n_splits=5, random_state=1, shuffle=True)
# evaluate model
scores1 = cross_val_score(algo, X[f0], y, scoring='accuracy', cv=cv, n_jobs=-1)
scores2 = cross_val_score(algo, X[f0], y, scoring='recall', cv=cv, n_jobs=-1)
scores3 = cross_val_score(algo, X[f0], y, scoring=my_scorer, cv=cv, n_jobs=-1)
scores4 = cross_val_score(algo, X[f0], y, scoring=my_scorer1, cv=cv, n_jobs=-1)
scores5 = cross_val_score(algo, X[f0], y, scoring=my_scorer2, cv=cv, n_jobs=-1)
scores6 = cross_val_score(algo, X[f0], y, scoring=my_scorer3, cv=cv, n_jobs=-1)
scores7 = cross_val_score(algo, X[f0], y, scoring='roc_auc', cv=cv, n_jobs=-1)
scores8 = cross_val_score(algo, X[f0], y, scoring=my_scorer4, cv=cv, n_jobs=-1)
scores9 = cross_val_score(algo, X[f0], y, scoring=my_scorer5, cv=cv, n_jobs=-1)
scores10 = cross_val_score(algo, X[f0], y, scoring=my_scorer6, cv=cv, n_jobs=-1)
scores11 = cross_val_score(algo, X[f0], y, scoring=my_scorer7, cv=cv, n_jobs=-1)
# report performance
print('Accuracy:',scores1)
print('moy_accuracy:',mean(scores1))
print("-------------------------------------------------")
print('sensibilité :',scores2)
print('moy_sensibilité: ',mean(scores2))
print("-------------------------------------------------")
print('spécificité :',scores3)
print('moy_spécificité:',mean(scores3))
print("-------------------------------------------------")
print('MCC :',scores4)
print('MCC: ',mean(scores4))
print("-------------------------------------------------")
print('precision-po:',scores5)
print('moy_precision-po:', mean(scores5))
print("-------------------------------------------------")
print('precision-ne :',scores6)
print('moy_precision-ne:',mean(scores6))
print("-------------------------------------------------")
print('AUC :',scores7)
print('moy_AUC: ',mean(scores7))
print("-------------------------------------------------")
print('VN :',scores8)
print('VP :',scores9)
print('FP :',scores10)
print('FN :',scores11)
print("-------------------------------------------------")
print("-------------------------------------------------")
# Out:
# Accuracy: [0.74509804 0.7254902  0.80392157 0.80392157 0.66      ]
# moy_accuracy: 0.7476862745098038
# -------------------------------------------------
# sensibilité : [0.70967742 0.72727273 0.66666667 0.8        0.75      ]
# moy_sensibilité:  0.7307233626588465
# -------------------------------------------------
# spécificité : [0.8        0.72413793 1.         0.80645161 0.57692308]
# moy_spécificité: 0.7815025241721572
# -------------------------------------------------
# MCC : [0.49777669 0.44791401 0.67202151 0.59783545 0.33092473]
# MCC:  0.5092944772955652
# -------------------------------------------------
# precision-po: [0.84615385 0.66666667 1.         0.72727273 0.62068966]
# moy_precision-po: 0.7721565790531308
# -------------------------------------------------
# precision-ne : [0.64       0.77777778 0.67741935 0.86206897 0.71428571]
# moy_precision-ne: 0.7343103624838886
# -------------------------------------------------
# AUC : [0.78467742 0.77899687 0.81587302 0.85322581 0.79326923]
# moy_AUC:  0.805208467530492
# -------------------------------------------------
# VN : [16 21 21 25 15]
# VP : [22 16 20 16 18]
# FP : [ 4  8  0  6 11]
# FN : [ 9  6 10  4  6]
# -------------------------------------------------
# -------------------------------------------------

# %% [markdown]
# # DFS

# %%
clmns=X.columns

# %%
clmns
# Out:
# Index(['X_long', 'Y_lat', 'Bovins', 'Volaille', 'Caprins', 'Ovins', 'Equides',
#        'Coniferes', 'ZoneAride', 'ZonePel',
#        ...
#        'Vent_Mars', 'Vent_Avril', 'Vent_Mai', 'Vent_Juin', 'Vent_Juill',
#        'Vent_Aout', 'Vent_Sept', 'Vent_Oct', 'Vent_Nov', 'Vent_Dec'],
#       dtype='object', length=225)

# %%
def transform(X, fs) :
  X_ = X.copy()
  for i in range(len(fs)) :
    if fs[i] == False :
      X_.drop([clmns[i]], axis=1, inplace=True)
  return X_

# %%
def Retransform (lst):
  Fs=[]      
  for i in range(225):
    if clmns[i] in lst :
       Fs.append(True)
    else :
       Fs.append(False)
  return Fs

# %%
lst= ['Min_IRM', 'Amp1_TempJ', 'Max_TempN', 'VarT_ann_NDVI', 'Var_EVI',
       'ProfAbs_Sub', 'IR_Moy', 'Rad_Mai', 'Tmax_Fev', 'Tmax_Avril']

# %%
Fs = Retransform (lst)

# %%
Fs
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False]

# %%
cv = KFold(n_splits=5, random_state=1, shuffle=True)
explored_models = []
scores_mcc= []
models_mm=[]
def explor_mcc(fs, mcc, algo) :
  if (sum(fs) < 5 or sum(fs) > 225) :
    return
  explored_models.append(fs)
  for i in range(225) :
    neighbor = fs.copy()
    neighbor[i] = not fs[i]
    if (neighbor not in explored_models) :
      score_mcc = cross_val_score(algo, transform(X, neighbor) , y, scoring=my_scorer1, cv=cv, n_jobs=-1)
      mean_score_mcc = np.mean(score_mcc)
      explored_models.append(neighbor)
      if (mean_score_mcc >= mcc) :
        models_mm.append(neighbor)
        print("mcc", mean_score_mcc)
        print("-----------")
        scores_mcc.append(mean_score_mcc)
        explor_mcc(neighbor, mean_score_mcc, algo)

# %%
transform(X,Fs)
# Out:
#      Min_IRM  Amp1_TempJ  Max_TempN  VarT_ann_NDVI  Var_EVI  ProfAbs_Sub  \
# 0       2690          96      14561              2        1         4143
# 1       3350         312      14705             13        0         1828
# 2       3350         312      14705             13        0         1828
# 3       2930         306      14690              8        0            0
# 4       2350         295      14719              1       35         6537
# ..       ...         ...        ...            ...      ...          ...
# 249      880         543      14675             52       47            0
# 250     1400         478      14743             51        7          846
# 251     1080         452      14666             84       70         1729
# 252      620           0          0             37       40         2786
# 253      990         366      14647             77       39         2264
#
#         IR_Moy  Rad_Mai   Tmax_Fev  Tmax_Avril
# 0     1.968750    24920  21.799999   22.600000
# 1     1.375000    24082  22.600000   24.600000
# 2     1.375000    24082  22.600000   24.600000
# 3     9.304688    24019  22.600000   24.600000
# 4     7.515625    24002  22.799999   24.700001
# ..         ...      ...        ...         ...
# 249  25.093750    23341  15.400000   18.900000
# 250   6.578125    23582  15.500000   18.700001
# 251  15.914062    23425  15.500000   18.900000
# 252  14.812500    23716  17.100000   19.799999
# 253  30.250000    23699  16.299999   19.000000
#
# [254 rows x 10 columns]

# %%
explor_mcc(Fs, 0.5092944772955652, algo)
# Out:
# mcc 0.5426020611174247
# -----------
# mcc 0.5435614028832442
# -----------
# mcc 0.5300144597731193
# -----------
# mcc 0.5382932941142033
# -----------
# mcc 0.5462778163031047
# -----------
# mcc 0.5350832458178822
# -----------
# mcc 0.5378781412979485
# -----------
# mcc 0.5514833256741802
# -----------
# mcc 0.5601675089972636
# -----------
# mcc 0.5608683217702446
# -----------
# mcc 0.5627103905911642
# -----------
# mcc 0.5623218680325367
# -----------
# mcc 0.5708489691184484
# -----------
# mcc 0.5688753206907832
# -----------
# mcc 0.5723066550875548
# -----------
# mcc 0.583034932070936
# -----------
# mcc 0.5832571800168307
# -----------
# mcc 0.5896566751397323
# -----------
# mcc 0.5958821319535278
# -----------
# mcc 0.5859976888504548
# -----------
# mcc 0.5898087457388905
# -----------
# mcc 0.5904048031347131
# -----------
# mcc 0.6009251669853655
# -----------
# mcc 0.587560695994102
# -----------
# mcc 0.5932336577010032
# -----------
# mcc 0.584785752037406
# -----------
# mcc 0.5883371798059123
# -----------
# mcc 0.5945809629492173
# -----------
# mcc 0.5877875507542092
# -----------
# mcc 0.5951222565306615
# -----------
# mcc 0.5855045122552823
# -----------
# mcc 0.5742403388988231
# -----------
# mcc 0.5782235836667107
# -----------
# mcc 0.5786996813022552
# -----------
# mcc 0.5803980534864642
# -----------
# mcc 0.5901091615983096
# -----------
# mcc 0.5953923063437228
# -----------
# mcc 0.5974733871731368
# -----------
# mcc 0.6112370233606537
# -----------
# mcc 0.6127796016722333
# -----------
# mcc 0.6010010227116217
# -----------
# mcc 0.6007893063829555
# -----------
# mcc 0.5999919825123681
# -----------
# mcc 0.5904285488763477
# -----------
# mcc 0.5942882263302639
# -----------
# mcc 0.6042723868332691
# -----------
# mcc 0.6067315423320542
# -----------
# mcc 0.6079009923876291
# -----------
# mcc 0.6090694013969025
# -----------
# mcc 0.6186542143077851
# -----------
# mcc 0.6262242130778907
# -----------
# mcc 0.630845068488487
# -----------
# mcc 0.615343035961411
# -----------
# mcc 0.6276132568480455
# -----------
# mcc 0.6127729869660857
# -----------
# mcc 0.6191231504694713
# -----------
# mcc 0.6134552985315256
# -----------
# mcc 0.626802672888843
# -----------
# mcc 0.6372162931483277
# -----------
# mcc 0.6137995733058448
# -----------
# mcc 0.6177886719439523
# -----------
# mcc 0.6237917574102487
# -----------
# mcc 0.6375006993172668
# -----------
# mcc 0.6426101106379193
# -----------
# mcc 0.6179218242629825
# -----------
# mcc 0.6055878437965342
# -----------
# mcc 0.6093699706669973
# -----------
# mcc 0.627618493992154
# -----------
# mcc 0.6390754031702953
# -----------
# mcc 0.656410856960471
# -----------
# mcc 0.6415550893324669
# -----------
# mcc 0.6442339981587246
# -----------
# mcc 0.6473886395255425
# -----------
# mcc 0.6401666124189448
# -----------
# mcc 0.6276610277757764
# -----------
# mcc 0.6081672949020691
# -----------
# mcc 0.6043945861051447
# -----------
# mcc 0.612474738915925
# -----------
# mcc 0.6066542448945211
# -----------
# mcc 0.6162399013356011
# -----------
# mcc 0.6274321426277403
# -----------
# mcc 0.6092166081947006
# -----------
# mcc 0.6108396915753892
# -----------
# mcc 0.6213250361237541
# -----------
# mcc 0.612725539015565
# -----------
# mcc 0.6129778708454706
# -----------
# mcc 0.6157593215127586
# -----------
# mcc 0.6168388159117333
# -----------
# mcc 0.6166829686267553
# -----------
# mcc 0.6056432537529135
# -----------
# mcc 0.6101529887436441
# -----------
# mcc 0.6193531488636265
# -----------
# mcc 0.6238576915763996
# -----------
# mcc 0.625632731114409
# -----------
# mcc 0.6227542199778953
# -----------
# mcc 0.6258001788298836
# -----------
# mcc 0.6162740715801419
# -----------
# mcc 0.620453138073573
# -----------
# mcc 0.6210178824051644
# -----------
# mcc 0.6208068307640523
# -----------
# mcc 0.6258343895610394
# -----------
# mcc 0.6222059592339242
# -----------
# mcc 0.6333974899380407
# -----------
# mcc 0.633049897914988
# -----------
# mcc 0.6334470427063683
# -----------
# mcc 0.6351186895012645
# -----------
# mcc 0.6150206483572098
# -----------
# mcc 0.6170363721325188
# -----------
# mcc 0.6171998772492824
# -----------
# mcc 0.6395001644625485
# -----------
# mcc 0.6269241648524733
# -----------
# mcc 0.6357866923209089
# -----------
# mcc 0.6403163480012857
# -----------
# mcc 0.6473469924358369
# -----------
# mcc 0.6501962269166331
# -----------
# mcc 0.654236201330477
# -----------
# mcc 0.6658968174575681
# -----------
# mcc 0.6537771601719928
# -----------
# mcc 0.6469118166762143
# -----------
# mcc 0.6533778441597906
# -----------
# mcc 0.6534198568580726
# -----------
# mcc 0.6276911425426389
# -----------
# mcc 0.6203997324929686
# -----------
# mcc 0.6174619676986766
# -----------
# mcc 0.6233434435173029
# -----------
# mcc 0.6252763838736712
# -----------
# mcc 0.6309255615665655
# -----------
# mcc 0.6354497172862725
# -----------
# mcc 0.6385650793709464
# -----------
# mcc 0.6344084814021891
# -----------
# mcc 0.6383979832886376
# -----------
# mcc 0.6281503792382013
# -----------
# mcc 0.6280252444293737
# -----------
# mcc 0.6316067126066556
# -----------
# mcc 0.6287836926004029
# -----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-185112823cb2> in <module>()
# ----> 1 explor_mcc(Fs, 0.5092944772955652, algo)
#
# <ipython-input-21-07add6788548> in explor_mcc(fs, mcc, algo)
#      19         print("-----------")
#      20         scores_mcc.append(mean_score_mcc)
# ---> 21         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-21-07add6788548> in explor_mcc(fs, mcc, algo)
#      19         print("-----------")
#      20         scores_mcc.append(mean_score_mcc)
# ---> 21         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-21-07add6788548> in explor_mcc(fs, mcc, algo)
#      19         print("-----------")
#      20         scores_mcc.append(mean_score_mcc)
# ---> 21         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-21-07add6788548> in explor_mcc(fs, mcc, algo)
#      19         print("-----------")
#      20         scores_mcc.append(mean_score_mcc)
# ---> 21         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-21-07add6788548> in explor_mcc(fs, mcc, algo)
#      19         print("-----------")
#      20         scores_mcc.append(mean_score_mcc)
# ---> 21         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-21-07add6788548> in explor_mcc(fs, mcc, algo)
#      19         print("-----------")
#      20         scores_mcc.append(mean_score_mcc)
# ---> 21         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-21-07add6788548> in explor_mcc(fs, mcc, algo)
#      19         print("-----------")
#      20         scores_mcc.append(mean_score_mcc)
# ---> 21         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-21-07add6788548> in explor_mcc(fs, mcc, algo)
#      19         print("-----------")
#      20         scores_mcc.append(mean_score_mcc)
# ---> 21         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-21-07add6788548> in explor_mcc(fs, mcc, algo)
#      19         print("-----------")
#      20         scores_mcc.append(mean_score_mcc)
# ---> 21         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-21-07add6788548> in explor_mcc(fs, mcc, algo)
#      19         print("-----------")
#      20         scores_mcc.append(mean_score_mcc)
# ---> 21         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-21-07add6788548> in explor_mcc(fs, mcc, algo)
#      19         print("-----------")
#      20         scores_mcc.append(mean_score_mcc)
# ---> 21         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-21-07add6788548> in explor_mcc(fs, mcc, algo)
#      19         print("-----------")
#      20         scores_mcc.append(mean_score_mcc)
# ---> 21         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-21-07add6788548> in explor_mcc(fs, mcc, algo)
#      19         print("-----------")
#      20         scores_mcc.append(mean_score_mcc)
# ---> 21         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-21-07add6788548> in explor_mcc(fs, mcc, algo)
#      19         print("-----------")
#      20         scores_mcc.append(mean_score_mcc)
# ---> 21         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-21-07add6788548> in explor_mcc(fs, mcc, algo)
#      19         print("-----------")
#      20         scores_mcc.append(mean_score_mcc)
# ---> 21         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-21-07add6788548> in explor_mcc(fs, mcc, algo)
#      19         print("-----------")
#      20         scores_mcc.append(mean_score_mcc)
# ---> 21         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-21-07add6788548> in explor_mcc(fs, mcc, algo)
#      11     neighbor[i] = not fs[i]
#      12     if (neighbor not in explored_models) :
# ---> 13       score_mcc = cross_val_score(algo, transform(X, neighbor) , y, scoring=my_scorer1, cv=cv, n_jobs=-1)
#      14       mean_score_mcc = np.mean(score_mcc)
#      15       explored_models.append(neighbor)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     518         fit_params=fit_params,
#     519         pre_dispatch=pre_dispatch,
# --> 520         error_score=error_score,
#     521     )
#     522     return cv_results["test_score"]
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     281             error_score=error_score,
#     282         )
# --> 283         for train, test in cv.split(X, y, groups)
#     284     )
#     285
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1054
#    1055             with self._backend.retrieval_context():
# -> 1056                 self.retrieve()
#    1057             # Make sure that we get a last message telling us we are done
#    1058             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in retrieve(self)
#     933             try:
#     934                 if getattr(self._backend, 'supports_timeout', False):
# --> 935                     self._output.extend(job.get(timeout=self.timeout))
#     936                 else:
#     937                     self._output.extend(job.get())
#
# /usr/local/lib/python3.7/dist-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# /usr/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     428                 return self.__get_result()
#     429
# --> 430             self._condition.wait(timeout)
#     431
#     432             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
len(explored_models)
# Out:
# 28389

# %%
len(models_mm)
# Out:
# 135

# %%
models_mm
# Out:
# [[False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  [True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
# ...
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False]]

# %% [markdown]
# # Modélisation

# %%
for i in range(len(models_mm)):
  print("-----------------------------------------------------------------------")
  print("-----------------------------------------------------------------------")
  print("les variables :")
  print(transform(X,models_mm[i]).columns)
  print("nombre des variables",len(transform(X,models_mm[i]).columns))
  # evaluate model
  scores1 = cross_val_score(algo, transform(X, models_mm[i]), y, scoring='accuracy', cv=cv, n_jobs=-1)
  scores2 = cross_val_score(algo, transform(X, models_mm[i]), y, scoring='recall', cv=cv, n_jobs=-1)
  scores3 = cross_val_score(algo, transform(X, models_mm[i]), y, scoring=my_scorer, cv=cv, n_jobs=-1)
  scores4 = cross_val_score(algo, transform(X, models_mm[i]), y, scoring=my_scorer1, cv=cv, n_jobs=-1)
  scores5 = cross_val_score(algo, transform(X, models_mm[i]), y, scoring=my_scorer2, cv=cv, n_jobs=-1)
  scores6 = cross_val_score(algo, transform(X, models_mm[i]), y, scoring=my_scorer3, cv=cv, n_jobs=-1)
  scores7 = cross_val_score(algo, transform(X, models_mm[i]), y, scoring='roc_auc', cv=cv, n_jobs=-1)
  scores8 = cross_val_score(algo, transform(X, models_mm[i]), y, scoring=my_scorer4, cv=cv, n_jobs=-1)
  scores9 = cross_val_score(algo, transform(X, models_mm[i]), y, scoring=my_scorer5, cv=cv, n_jobs=-1)
  scores10 = cross_val_score(algo, transform(X, models_mm[i]), y, scoring=my_scorer6, cv=cv, n_jobs=-1)
  scores11 = cross_val_score(algo, transform(X, models_mm[i]), y, scoring=my_scorer7, cv=cv, n_jobs=-1)
  # report performance
  print('Accuracy:',scores1)
  print('moy_accuracy:',mean(scores1))
  print("-------------------------------------------------")
  print('sensibilité :',scores2)
  print('moy_sensibilité: ',mean(scores2))
  print("-------------------------------------------------")
  print('spécificité :',scores3)
  print('moy_spécificité:',mean(scores3))
  print("-------------------------------------------------")
  print('MCC :',scores4)
  print('MCC: ',mean(scores4))
  print("-------------------------------------------------")
  print('precision-po:',scores5)
  print('moy_precision-po:', mean(scores5))
  print("-------------------------------------------------")
  print('precision-ne :',scores6)
  print('moy_precision-ne:',mean(scores6))
  print("-------------------------------------------------")
  print('AUC :',scores7)
  print('moy_AUC: ',mean(scores7))
  print("-------------------------------------------------")
  print('VN :',scores8)
  print('VP :',scores9)
  print('FP :',scores10)
  print('FN :',scores11)
# Out:
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Min_IRM', 'Amp1_TempJ', 'Max_TempN', 'Ph1_TempN', 'VarT_ann_NDVI',
#        'Var_EVI', 'ProfAbs_Sub', 'IR_Moy', 'Rad_Mai', 'Tmax_Fev',
#        'Tmax_Avril'],
#       dtype='object')
# nombre des variables 11
# Accuracy: [0.76470588 0.7254902  0.80392157 0.80392157 0.7       ]
# moy_accuracy: 0.7596078431372548
# -------------------------------------------------
# sensibilité : [0.64516129 0.72727273 0.66666667 0.8        0.75      ]
# moy_sensibilité:  0.7178201368523949
# -------------------------------------------------
# spécificité : [0.95       0.72413793 1.         0.80645161 0.65384615]
# moy_spécificité: 0.8268871395567725
# -------------------------------------------------
# MCC : [0.59041889 0.44791401 0.67202151 0.59783545 0.40482045]
# MCC:  0.5426020611174247
# -------------------------------------------------
# precision-po: [0.95238095 0.66666667 1.         0.72727273 0.66666667]
# moy_precision-po: 0.8025974025974026
# -------------------------------------------------
# precision-ne : [0.63333333 0.77777778 0.67741935 0.86206897 0.73913043]
# moy_precision-ne: 0.737945973249934
# -------------------------------------------------
# AUC : [0.78629032 0.74294671 0.80952381 0.84354839 0.76923077]
# moy_AUC:  0.7903079993791897
# -------------------------------------------------
# VN : [19 21 21 25 17]
# VP : [20 16 20 16 18]
# FP : [1 8 0 6 9]
# FN : [11  6 10  4  6]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Min_IRM', 'Amp1_TempJ', 'Max_TempN', 'Ph1_TempN', 'VarT_ann_NDVI',
#        'Var_EVI', 'ProfAbs_Sub', 'Geom_maj', 'IR_Moy', 'Rad_Mai', 'Tmax_Fev',
#        'Tmax_Avril'],
#       dtype='object')
# nombre des variables 12
# Accuracy: [0.70588235 0.76470588 0.82352941 0.84313725 0.68      ]
# moy_accuracy: 0.7634509803921569
# -------------------------------------------------
# sensibilité : [0.61290323 0.72727273 0.7        0.85       0.70833333]
# moy_sensibilité:  0.7197018572825025
# -------------------------------------------------
# spécificité : [0.85       0.79310345 1.         0.83870968 0.65384615]
# moy_spécificité: 0.8271318559082742
# -------------------------------------------------
# MCC : [0.45632652 0.52037618 0.7        0.67892483 0.36217949]
# MCC:  0.5435614028832442
# -------------------------------------------------
# precision-po: [0.86363636 0.72727273 1.         0.77272727 0.65384615]
# moy_precision-po: 0.8034965034965035
# -------------------------------------------------
# precision-ne : [0.5862069  0.79310345 0.7        0.89655172 0.70833333]
# moy_precision-ne: 0.7368390804597702
# -------------------------------------------------
# AUC : [0.77177419 0.79545455 0.81746032 0.84677419 0.7724359 ]
# moy_AUC:  0.800779829489507
# -------------------------------------------------
# VN : [17 23 21 26 17]
# VP : [19 16 21 17 17]
# FP : [3 6 0 5 9]
# FN : [12  6  9  3  7]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Min_IRM', 'Amp1_TempJ', 'Max_TempN', 'VarT_ann_NDVI', 'Var_EVI',
#        'ProfAbs_Sub', 'Sol_Sable', 'IR_Moy', 'Rad_Mai', 'Tmax_Fev',
#        'Tmax_Avril'],
#       dtype='object')
# nombre des variables 11
# Accuracy: [0.80392157 0.74509804 0.76470588 0.80392157 0.66      ]
# moy_accuracy: 0.7555294117647058
# -------------------------------------------------
# sensibilité : [0.70967742 0.72727273 0.63333333 0.8        0.75      ]
# moy_sensibilité:  0.7240566959921798
# -------------------------------------------------
# spécificité : [0.95       0.75862069 0.95238095 0.80645161 0.57692308]
# moy_spécificité: 0.8088752663724854
# -------------------------------------------------
# MCC : [0.64726859 0.48362464 0.59041889 0.59783545 0.33092473]
# MCC:  0.5300144597731193
# -------------------------------------------------
# precision-po: [0.95652174 0.69565217 0.95       0.72727273 0.62068966]
# moy_precision-po: 0.7900272590977238
# -------------------------------------------------
# precision-ne : [0.67857143 0.78571429 0.64516129 0.86206897 0.71428571]
# moy_precision-ne: 0.7371603368822501
# -------------------------------------------------
# AUC : [0.81612903 0.76332288 0.78095238 0.85967742 0.77083333]
# moy_AUC:  0.7981830099822314
# -------------------------------------------------
# VN : [19 22 20 25 15]
# VP : [22 16 19 16 18]
# FP : [ 1  7  1  6 11]
# FN : [ 9  6 11  4  6]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['X_long', 'Min_IRM', 'Amp1_TempJ', 'Max_TempN', 'VarT_ann_NDVI',
#        'Var_EVI', 'ProfAbs_Sub', 'Sol_Sable', 'IR_Moy', 'Rad_Mai', 'Tmax_Fev',
#        'Tmax_Avril'],
#       dtype='object')
# nombre des variables 12
# Accuracy: [0.80392157 0.76470588 0.78431373 0.80392157 0.66      ]
# moy_accuracy: 0.7633725490196079
# -------------------------------------------------
# sensibilité : [0.77419355 0.72727273 0.66666667 0.85       0.75      ]
# moy_sensibilité:  0.7536265884652982
# -------------------------------------------------
# spécificité : [0.85       0.79310345 0.95238095 0.77419355 0.57692308]
# moy_spécificité: 0.7893202051933976
# -------------------------------------------------
# MCC : [0.61055897 0.52037618 0.61904762 0.61055897 0.33092473]
# MCC:  0.5382932941142033
# -------------------------------------------------
# precision-po: [0.88888889 0.72727273 0.95238095 0.70833333 0.62068966]
# moy_precision-po: 0.7795131114096632
# -------------------------------------------------
# precision-ne : [0.70833333 0.79310345 0.66666667 0.88888889 0.71428571]
# moy_precision-ne: 0.754255610290093
# -------------------------------------------------
# AUC : [0.82016129 0.77272727 0.82063492 0.85645161 0.76121795]
# moy_AUC:  0.8062386090611897
# -------------------------------------------------
# VN : [17 23 20 24 15]
# VP : [24 16 20 17 18]
# FP : [ 3  6  1  7 11]
# FN : [ 7  6 10  3  6]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Amp3_IRM', 'Min_IRM', 'Amp1_TempJ', 'Max_TempN', 'VarT_ann_NDVI',
#        'Var_EVI', 'ProfAbs_Sub', 'Sol_Sable', 'IR_Moy', 'Rad_Mai', 'Tmax_Fev',
#        'Tmax_Avril'],
#       dtype='object')
# nombre des variables 12
# Accuracy: [0.80392157 0.7254902  0.82352941 0.80392157 0.68      ]
# moy_accuracy: 0.7673725490196077
# -------------------------------------------------
# sensibilité : [0.74193548 0.72727273 0.73333333 0.85       0.75      ]
# moy_sensibilité:  0.7605083088954057
# -------------------------------------------------
# spécificité : [0.9        0.72413793 0.95238095 0.77419355 0.61538462]
# moy_spécificité: 0.7932194094374295
# -------------------------------------------------
# MCC : [0.6269466  0.44791401 0.67821992 0.61055897 0.36774959]
# MCC:  0.5462778163031047
# -------------------------------------------------
# precision-po: [0.92       0.66666667 0.95652174 0.70833333 0.64285714]
# moy_precision-po: 0.7788757763975156
# -------------------------------------------------
# precision-ne : [0.69230769 0.77777778 0.71428571 0.88888889 0.72727273]
# moy_precision-ne: 0.7601065601065601
# -------------------------------------------------
# AUC : [0.80725806 0.75548589 0.80634921 0.83387097 0.77403846]
# moy_AUC:  0.7954005187125321
# -------------------------------------------------
# VN : [18 21 20 24 16]
# VP : [23 16 22 17 18]
# FP : [ 2  8  1  7 10]
# FN : [8 6 8 3 6]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Min_IRM', 'Var_IRM', 'Amp1_TempJ', 'Max_TempN', 'VarT_ann_NDVI',
#        'Var_EVI', 'ProfAbs_Sub', 'Sol_Sable', 'IR_Moy', 'Rad_Mai', 'Tmax_Fev',
#        'Tmax_Avril'],
#       dtype='object')
# nombre des variables 12
# Accuracy: [0.78431373 0.7254902  0.82352941 0.78431373 0.68      ]
# moy_accuracy: 0.7595294117647058
# -------------------------------------------------
# sensibilité : [0.70967742 0.72727273 0.7        0.8        0.75      ]
# moy_sensibilité:  0.7373900293255131
# -------------------------------------------------
# spécificité : [0.9        0.72413793 1.         0.77419355 0.61538462]
# moy_spécificité: 0.8027432189612391
# -------------------------------------------------
# MCC : [0.59635993 0.44791401 0.7        0.56339271 0.36774959]
# MCC:  0.5350832458178822
# -------------------------------------------------
# precision-po: [0.91666667 0.66666667 1.         0.69565217 0.64285714]
# moy_precision-po: 0.7843685300207038
# -------------------------------------------------
# precision-ne : [0.66666667 0.77777778 0.7        0.85714286 0.72727273]
# moy_precision-ne: 0.7457720057720059
# -------------------------------------------------
# AUC : [0.81129032 0.75705329 0.81111111 0.83225806 0.75801282]
# moy_AUC:  0.7939451220513513
# -------------------------------------------------
# VN : [18 21 21 24 16]
# VP : [22 16 21 16 18]
# FP : [ 2  8  0  7 10]
# FN : [9 6 9 4 6]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Min_IRM', 'Var_IRM', 'Amp1_TempJ', 'Max_TempN', 'VarT_ann_NDVI',
#        'Var_EVI', 'ProfAbs_Sub', 'Sol_Sable', 'IR_Moy', 'Bio_Pre_Saison',
#        'Rad_Mai', 'Tmax_Fev', 'Tmax_Avril'],
#       dtype='object')
# nombre des variables 13
# Accuracy: [0.78431373 0.74509804 0.78431373 0.78431373 0.7       ]
# moy_accuracy: 0.7596078431372548
# -------------------------------------------------
# sensibilité : [0.67741935 0.72727273 0.66666667 0.8        0.75      ]
# moy_sensibilité:  0.7242717497556207
# -------------------------------------------------
# spécificité : [0.95       0.75862069 0.95238095 0.77419355 0.65384615]
# moy_spécificité: 0.8178082688538751
# -------------------------------------------------
# MCC : [0.61850529 0.48362464 0.61904762 0.56339271 0.40482045]
# MCC:  0.5378781412979485
# -------------------------------------------------
# precision-po: [0.95454545 0.69565217 0.95238095 0.69565217 0.66666667]
# moy_precision-po: 0.7929794842838321
# -------------------------------------------------
# precision-ne : [0.65517241 0.78571429 0.66666667 0.85714286 0.73913043]
# moy_precision-ne: 0.7407653316199043
# -------------------------------------------------
# AUC : [0.8016129  0.7460815  0.80952381 0.85       0.76282051]
# moy_AUC:  0.7940077460544647
# -------------------------------------------------
# VN : [19 22 20 24 17]
# VP : [21 16 20 16 18]
# FP : [1 7 1 7 9]
# FN : [10  6 10  4  6]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Min_IRM', 'Var_IRM', 'Amp1_TempJ', 'Max_TempN', 'VarT_ann_NDVI',
#        'Var_EVI', 'ProfAbs_Sub', 'Sol_Sable', 'IR_Moy', 'Rad_Mai', 'Tmax_Fev',
#        'Tmax_Avril', 'Vent_Aout'],
#       dtype='object')
# nombre des variables 13
# Accuracy: [0.82352941 0.78431373 0.74509804 0.80392157 0.68      ]
# moy_accuracy: 0.7673725490196079
# -------------------------------------------------
# sensibilité : [0.77419355 0.72727273 0.6        0.85       0.75      ]
# moy_sensibilité:  0.7402932551319649
# -------------------------------------------------
# spécificité : [0.9        0.82758621 0.95238095 0.77419355 0.61538462]
# moy_spécificité: 0.8139090646098431
# -------------------------------------------------
# MCC : [0.65845145 0.55837073 0.56228588 0.61055897 0.36774959]
# MCC:  0.5514833256741802
# -------------------------------------------------
# precision-po: [0.92307692 0.76190476 0.94736842 0.70833333 0.64285714]
# moy_precision-po: 0.7967081164449585
# -------------------------------------------------
# precision-ne : [0.72       0.8        0.625      0.88888889 0.72727273]
# moy_precision-ne: 0.7522323232323233
# -------------------------------------------------
# AUC : [0.83467742 0.77742947 0.81269841 0.85       0.81891026]
# moy_AUC:  0.8187431111096295
# -------------------------------------------------
# VN : [18 24 20 24 16]
# VP : [24 16 18 17 18]
# FP : [ 2  5  1  7 10]
# FN : [ 7  6 12  3  6]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Min_IRM', 'Var_IRM', 'Amp1_TempJ', 'Amp3_TempN', 'Max_TempN',
#        'VarT_ann_NDVI', 'Var_EVI', 'ProfAbs_Sub', 'Sol_Sable', 'IR_Moy',
#        'Rad_Mai', 'Tmax_Fev', 'Tmax_Avril', 'Vent_Aout'],
#       dtype='object')
# nombre des variables 14
# Accuracy: [0.82352941 0.7254902  0.82352941 0.76470588 0.72      ]
# moy_accuracy: 0.7714509803921568
# -------------------------------------------------
# sensibilité : [0.74193548 0.77272727 0.73333333 0.8        0.83333333]
# moy_sensibilité:  0.7762658846529814
# -------------------------------------------------
# spécificité : [0.95       0.68965517 0.95238095 0.74193548 0.61538462]
# moy_spécificité: 0.7898712448100658
# -------------------------------------------------
# MCC : [0.67682119 0.45809442 0.67821992 0.53009771 0.45760432]
# MCC:  0.5601675089972636
# -------------------------------------------------
# precision-po: [0.95833333 0.65384615 0.95652174 0.66666667 0.66666667]
# moy_precision-po: 0.780406911928651
# -------------------------------------------------
# precision-ne : [0.7037037  0.8        0.71428571 0.85185185 0.8       ]
# moy_precision-ne: 0.7739682539682539
# -------------------------------------------------
# AUC : [0.84354839 0.78683386 0.85396825 0.81129032 0.81730769]
# moy_AUC:  0.8225897023505478
# -------------------------------------------------
# VN : [19 20 20 23 16]
# VP : [23 17 22 16 20]
# FP : [ 1  9  1  8 10]
# FN : [8 5 8 4 4]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['VegCul', 'Min_IRM', 'Var_IRM', 'Amp1_TempJ', 'Amp3_TempN', 'Max_TempN',
#        'VarT_ann_NDVI', 'Var_EVI', 'ProfAbs_Sub', 'Sol_Sable', 'IR_Moy',
#        'Rad_Mai', 'Tmax_Fev', 'Tmax_Avril', 'Vent_Aout'],
#       dtype='object')
# nombre des variables 15
# Accuracy: [0.82352941 0.74509804 0.76470588 0.78431373 0.72      ]
# moy_accuracy: 0.7675294117647058
# -------------------------------------------------
# sensibilité : [0.77419355 0.77272727 0.6        0.85       0.83333333]
# moy_sensibilité:  0.7660508308895406
# -------------------------------------------------
# spécificité : [0.9        0.72413793 1.         0.74193548 0.61538462]
# moy_spécificité: 0.7962916060580132
# -------------------------------------------------
# MCC : [0.65845145 0.49225739 0.61791438 0.57811407 0.45760432]
# MCC:  0.5608683217702446
# -------------------------------------------------
# precision-po: [0.92307692 0.68       1.         0.68       0.66666667]
# moy_precision-po: 0.7899487179487179
# -------------------------------------------------
# precision-ne : [0.72       0.80769231 0.63636364 0.88461538 0.8       ]
# moy_precision-ne: 0.7697342657342657
# -------------------------------------------------
# AUC : [0.82177419 0.79153605 0.83968254 0.82258065 0.81730769]
# moy_AUC:  0.8185762241713299
# -------------------------------------------------
# VN : [18 21 21 23 16]
# VP : [24 17 18 17 20]
# FP : [ 2  8  0  8 10]
# FN : [ 7  5 12  3  4]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['VegCul', 'Min_IRM', 'Var_IRM', 'Amp1_TempJ', 'Amp3_TempN', 'Max_TempN',
#        'Ph2_TempN', 'VarT_ann_NDVI', 'Var_EVI', 'ProfAbs_Sub', 'Sol_Sable',
#        'IR_Moy', 'Rad_Mai', 'Tmax_Fev', 'Tmax_Avril', 'Vent_Aout'],
#       dtype='object')
# nombre des variables 16
# Accuracy: [0.78431373 0.78431373 0.82352941 0.78431373 0.68      ]
# moy_accuracy: 0.7712941176470588
# -------------------------------------------------
# sensibilité : [0.70967742 0.77272727 0.7        0.85       0.79166667]
# moy_sensibilité:  0.7648142717497557
# -------------------------------------------------
# spécificité : [0.9        0.79310345 1.         0.74193548 0.57692308]
# moy_spécificité: 0.8023924018139812
# -------------------------------------------------
# MCC : [0.59635993 0.5631887  0.7        0.57811407 0.37588926]
# MCC:  0.5627103905911642
# -------------------------------------------------
# precision-po: [0.91666667 0.73913043 1.         0.68       0.63333333]
# moy_precision-po: 0.7938260869565218
# -------------------------------------------------
# precision-ne : [0.66666667 0.82142857 0.7        0.88461538 0.75      ]
# moy_precision-ne: 0.7645421245421246
# -------------------------------------------------
# AUC : [0.81370968 0.79310345 0.82857143 0.80967742 0.73557692]
# moy_AUC:  0.7961277793396814
# -------------------------------------------------
# VN : [18 23 21 23 15]
# VP : [22 17 21 17 19]
# FP : [ 2  6  0  8 11]
# FN : [9 5 9 3 5]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['VegCul', 'Min_IRM', 'Var_IRM', 'Amp1_TempJ', 'Amp3_TempN', 'Max_TempN',
#        'VarT_ann_NDVI', 'VarT_tri_EVI', 'Var_EVI', 'ProfAbs_Sub', 'Sol_Sable',
#        'IR_Moy', 'Rad_Mai', 'Tmax_Fev', 'Tmax_Avril', 'Vent_Aout'],
#       dtype='object')
# nombre des variables 16
# Accuracy: [0.74509804 0.74509804 0.78431373 0.82352941 0.74      ]
# moy_accuracy: 0.7676078431372548
# -------------------------------------------------
# sensibilité : [0.64516129 0.77272727 0.63333333 0.85       0.83333333]
# moy_sensibilité:  0.746911045943304
# -------------------------------------------------
# spécificité : [0.9        0.72413793 1.         0.80645161 0.65384615]
# moy_spécificité: 0.8168871395567725
# -------------------------------------------------
# MCC : [0.53741591 0.49225739 0.64468985 0.64410346 0.49314274]
# MCC:  0.5623218680325367
# -------------------------------------------------
# precision-po: [0.90909091 0.68       1.         0.73913043 0.68965517]
# moy_precision-po: 0.8035753032574622
# -------------------------------------------------
# precision-ne : [0.62068966 0.80769231 0.65625    0.89285714 0.80952381]
# moy_precision-ne: 0.7574025830491348
# -------------------------------------------------
# AUC : [0.78387097 0.78840125 0.83492063 0.81451613 0.85416667]
# moy_AUC:  0.8151751304559982
# -------------------------------------------------
# VN : [18 21 21 25 17]
# VP : [20 17 19 17 20]
# FP : [2 8 0 6 9]
# FN : [11  5 11  3  4]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['VegCul', 'ZoneUrbaine', 'Min_IRM', 'Var_IRM', 'Amp1_TempJ',
#        'Amp3_TempN', 'Max_TempN', 'VarT_ann_NDVI', 'VarT_tri_EVI', 'Var_EVI',
#        'ProfAbs_Sub', 'Sol_Sable', 'IR_Moy', 'Rad_Mai', 'Tmax_Fev',
#        'Tmax_Avril', 'Vent_Aout'],
#       dtype='object')
# nombre des variables 17
# Accuracy: [0.76470588 0.74509804 0.78431373 0.80392157 0.76      ]
# moy_accuracy: 0.7716078431372548
# -------------------------------------------------
# sensibilité : [0.64516129 0.77272727 0.63333333 0.8        0.83333333]
# moy_sensibilité:  0.7369110459433041
# -------------------------------------------------
# spécificité : [0.95       0.72413793 1.         0.80645161 0.69230769]
# moy_spécificité: 0.8345794472490802
# -------------------------------------------------
# MCC : [0.59041889 0.49225739 0.64468985 0.59783545 0.52904327]
# MCC:  0.5708489691184484
# -------------------------------------------------
# precision-po: [0.95238095 0.68       1.         0.72727273 0.71428571]
# moy_precision-po: 0.8147878787878788
# -------------------------------------------------
# precision-ne : [0.63333333 0.80769231 0.65625    0.86206897 0.81818182]
# moy_precision-ne: 0.7555052849449402
# -------------------------------------------------
# AUC : [0.78790323 0.79623824 0.85238095 0.82903226 0.8349359 ]
# moy_AUC:  0.8200981156403848
# -------------------------------------------------
# VN : [19 21 21 25 18]
# VP : [20 17 19 16 20]
# FP : [1 8 0 6 8]
# FN : [11  5 11  4  4]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Min_IRM', 'Var_IRM', 'Amp1_TempJ', 'Amp3_TempN', 'Max_TempN',
#        'Var_EVI', 'ProfAbs_Sub', 'Sol_Sable', 'IR_Moy', 'Rad_Mai', 'Tmax_Fev',
#        'Tmax_Avril', 'Vent_Aout'],
#       dtype='object')
# nombre des variables 13
# Accuracy: [0.80392157 0.7254902  0.80392157 0.80392157 0.74      ]
# moy_accuracy: 0.7754509803921568
# -------------------------------------------------
# sensibilité : [0.77419355 0.77272727 0.66666667 0.85       0.83333333]
# moy_sensibilité:  0.7793841642228739
# -------------------------------------------------
# spécificité : [0.85       0.68965517 1.         0.77419355 0.65384615]
# moy_spécificité: 0.7935389749294088
# -------------------------------------------------
# MCC : [0.61055897 0.45809442 0.67202151 0.61055897 0.49314274]
# MCC:  0.5688753206907832
# -------------------------------------------------
# precision-po: [0.88888889 0.65384615 1.         0.70833333 0.68965517]
# moy_precision-po: 0.7881447096964338
# -------------------------------------------------
# precision-ne : [0.70833333 0.8        0.67741935 0.88888889 0.80952381]
# moy_precision-ne: 0.7768330773169483
# -------------------------------------------------
# AUC : [0.82822581 0.76959248 0.83650794 0.82741935 0.8525641 ]
# moy_AUC:  0.822861935370278
# -------------------------------------------------
# VN : [17 20 21 24 17]
# VP : [24 17 20 17 20]
# FP : [3 9 0 7 9]
# FN : [ 7  5 10  3  4]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Min_IRM', 'Var_IRM', 'Amp1_TempJ', 'Amp3_TempN', 'Max_TempN',
#        'VarT_ann_NDVI', 'Var_EVI', 'ProfAbs_Sub', 'Sol_Sable', 'IR_Moy',
#        'Prec_Juill', 'Rad_Mai', 'Tmax_Fev', 'Tmax_Avril', 'Vent_Aout'],
#       dtype='object')
# nombre des variables 15
# Accuracy: [0.80392157 0.80392157 0.80392157 0.76470588 0.74      ]
# moy_accuracy: 0.7832941176470589
# -------------------------------------------------
# sensibilité : [0.77419355 0.77272727 0.73333333 0.75       0.875     ]
# moy_sensibilité:  0.7810508308895405
# -------------------------------------------------
# spécificité : [0.85       0.82758621 0.9047619  0.77419355 0.61538462]
# moy_spécificité: 0.7943852550860337
# -------------------------------------------------
# MCC : [0.61055897 0.60031348 0.62917039 0.51674606 0.50474437]
# MCC:  0.5723066550875548
# -------------------------------------------------
# precision-po: [0.88888889 0.77272727 0.91666667 0.68181818 0.67741935]
# moy_precision-po: 0.7875040729879439
# -------------------------------------------------
# precision-ne : [0.70833333 0.82758621 0.7037037  0.82758621 0.84210526]
# moy_precision-ne: 0.781862942797607
# -------------------------------------------------
# AUC : [0.81854839 0.77272727 0.82698413 0.82580645 0.80929487]
# moy_AUC:  0.8106722220431898
# -------------------------------------------------
# VN : [17 24 19 24 16]
# VP : [24 17 22 15 21]
# FP : [ 3  5  2  7 10]
# FN : [7 5 8 5 3]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Min_IRM', 'Var_IRM', 'Amp1_TempJ', 'VarT_bi_TempJ', 'Amp3_TempN',
#        'Max_TempN', 'VarT_ann_NDVI', 'Var_EVI', 'ProfAbs_Sub', 'Sol_Sable',
#        'IR_Moy', 'Prec_Juill', 'Rad_Mai', 'Tmax_Fev', 'Tmax_Avril',
#        'Vent_Aout'],
#       dtype='object')
# nombre des variables 16
# Accuracy: [0.82352941 0.76470588 0.80392157 0.76470588 0.78      ]
# moy_accuracy: 0.7873725490196077
# -------------------------------------------------
# sensibilité : [0.80645161 0.77272727 0.7        0.8        0.83333333]
# moy_sensibilité:  0.7825024437927663
# -------------------------------------------------
# spécificité : [0.85       0.75862069 0.95238095 0.74193548 0.73076923]
# moy_spécificité: 0.8067412713352647
# -------------------------------------------------
# MCC : [0.64410346 0.52723211 0.64827789 0.53009771 0.56546349]
# MCC:  0.583034932070936
# -------------------------------------------------
# precision-po: [0.89285714 0.70833333 0.95454545 0.66666667 0.74074074]
# moy_precision-po: 0.7926286676286676
# -------------------------------------------------
# precision-ne : [0.73913043 0.81481481 0.68965517 0.85185185 0.82608696]
# moy_precision-ne: 0.7843078460769615
# -------------------------------------------------
# AUC : [0.82822581 0.77899687 0.86666667 0.83064516 0.83173077]
# moy_AUC:  0.8272530537686265
# -------------------------------------------------
# VN : [17 22 20 23 19]
# VP : [25 17 21 16 20]
# FP : [3 7 1 8 7]
# FN : [6 5 9 4 4]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Min_IRM', 'Var_IRM', 'Amp1_TempJ', 'VarT_bi_TempJ', 'Amp3_TempN',
#        'VarT_ann_NDVI', 'Var_EVI', 'ProfAbs_Sub', 'Sol_Sable', 'IR_Moy',
#        'Prec_Juill', 'Rad_Mai', 'Tmax_Fev', 'Tmax_Avril', 'Vent_Aout'],
#       dtype='object')
# nombre des variables 15
# Accuracy: [0.84313725 0.78431373 0.80392157 0.80392157 0.68      ]
# moy_accuracy: 0.7830588235294118
# -------------------------------------------------
# sensibilité : [0.77419355 0.77272727 0.7        0.85       0.83333333]
# moy_sensibilité:  0.7860508308895406
# -------------------------------------------------
# spécificité : [0.95       0.79310345 0.95238095 0.77419355 0.53846154]
# moy_spécificité: 0.8016278975010899
# -------------------------------------------------
# MCC : [0.70728397 0.5631887  0.64827789 0.61055897 0.38697637]
# MCC:  0.5832571800168307
# -------------------------------------------------
# precision-po: [0.96       0.73913043 0.95454545 0.70833333 0.625     ]
# moy_precision-po: 0.7974018445322794
# -------------------------------------------------
# precision-ne : [0.73076923 0.82142857 0.68965517 0.88888889 0.77777778]
# moy_precision-ne: 0.7817039282556524
# -------------------------------------------------
# AUC : [0.84112903 0.77899687 0.83968254 0.83709677 0.83333333]
# moy_AUC:  0.8260477089342494
# -------------------------------------------------
# VN : [19 23 20 24 14]
# VP : [24 17 21 17 20]
# FP : [ 1  6  1  7 12]
# FN : [7 5 9 3 4]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Min_IRM', 'Var_IRM', 'Amp1_TempJ', 'VarT_bi_TempJ', 'Amp3_TempN',
#        'Max_TempN', 'VarT_ann_NDVI', 'ProfAbs_Sub', 'Sol_Sable', 'IR_Moy',
#        'Prec_Juill', 'Rad_Mai', 'Tmax_Fev', 'Tmax_Avril', 'Vent_Aout'],
#       dtype='object')
# nombre des variables 15
# Accuracy: [0.76470588 0.84313725 0.78431373 0.80392157 0.74      ]
# moy_accuracy: 0.7872156862745099
# -------------------------------------------------
# sensibilité : [0.70967742 0.77272727 0.66666667 0.85       0.83333333]
# moy_sensibilité:  0.7664809384164223
# -------------------------------------------------
# spécificité : [0.85       0.89655172 0.95238095 0.77419355 0.65384615]
# moy_spécificité: 0.825394475750427
# -------------------------------------------------
# MCC : [0.54660922 0.67892483 0.61904762 0.61055897 0.49314274]
# MCC:  0.5896566751397323
# -------------------------------------------------
# precision-po: [0.88       0.85       0.95238095 0.70833333 0.68965517]
# moy_precision-po: 0.8160738916256157
# -------------------------------------------------
# precision-ne : [0.65384615 0.83870968 0.66666667 0.88888889 0.80952381]
# moy_precision-ne: 0.7715270392689748
# -------------------------------------------------
# AUC : [0.82177419 0.79780564 0.85873016 0.83225806 0.85416667]
# moy_AUC:  0.8329469452189141
# -------------------------------------------------
# VN : [17 26 20 24 17]
# VP : [22 17 20 17 20]
# FP : [3 3 1 7 9]
# FN : [ 9  5 10  3  4]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Min_IRM', 'Var_IRM', 'Amp1_TempJ', 'VarT_bi_TempJ', 'Amp3_TempN',
#        'Max_TempN', 'VarT_ann_NDVI', 'ProfAbs_Sub', 'Sol_Sable', 'IPT_Med',
#        'IR_Moy', 'Prec_Juill', 'Rad_Mai', 'Tmax_Fev', 'Tmax_Avril',
#        'Vent_Aout'],
#       dtype='object')
# nombre des variables 16
# Accuracy: [0.82352941 0.82352941 0.76470588 0.78431373 0.78      ]
# moy_accuracy: 0.7952156862745097
# -------------------------------------------------
# sensibilité : [0.77419355 0.81818182 0.7        0.8        0.83333333]
# moy_sensibilité:  0.7851417399804496
# -------------------------------------------------
# spécificité : [0.9        0.82758621 0.85714286 0.77419355 0.73076923]
# moy_spécificité: 0.8179383686391473
# -------------------------------------------------
# MCC : [0.65845145 0.64275275 0.54935027 0.56339271 0.56546349]
# MCC:  0.5958821319535278
# -------------------------------------------------
# precision-po: [0.92307692 0.7826087  0.875      0.69565217 0.74074074]
# moy_precision-po: 0.8034157066765764
# -------------------------------------------------
# precision-ne : [0.72       0.85714286 0.66666667 0.85714286 0.82608696]
# moy_precision-ne: 0.7854078674948239
# -------------------------------------------------
# AUC : [0.8266129  0.81034483 0.86031746 0.84677419 0.84615385]
# moy_AUC:  0.8380406461663414
# -------------------------------------------------
# VN : [18 24 18 24 19]
# VP : [24 18 21 16 20]
# FP : [2 5 3 7 7]
# FN : [7 4 9 4 4]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Min_IRM', 'Var_IRM', 'Amp1_TempJ', 'VarT_bi_TempJ', 'Amp3_TempN',
#        'Max_TempN', 'VarT_ann_NDVI', 'Var_EVI', 'ProfAbs_Sub', 'Sol_Sable',
#        'Geom_maj', 'IR_Moy', 'Prec_Juill', 'Rad_Mai', 'Tmax_Fev', 'Tmax_Avril',
#        'Vent_Aout'],
#       dtype='object')
# nombre des variables 17
# Accuracy: [0.76470588 0.80392157 0.80392157 0.80392157 0.74      ]
# moy_accuracy: 0.7832941176470589
# -------------------------------------------------
# sensibilité : [0.64516129 0.77272727 0.7        0.8        0.83333333]
# moy_sensibilité:  0.7502443792766373
# -------------------------------------------------
# spécificité : [0.95       0.82758621 0.95238095 0.80645161 0.65384615]
# moy_spécificité: 0.8380529852053769
# -------------------------------------------------
# MCC : [0.59041889 0.60031348 0.64827789 0.59783545 0.49314274]
# MCC:  0.5859976888504548
# -------------------------------------------------
# precision-po: [0.95238095 0.77272727 0.95454545 0.72727273 0.68965517]
# moy_precision-po: 0.8193163158680399
# -------------------------------------------------
# precision-ne : [0.63333333 0.82758621 0.68965517 0.86206897 0.80952381]
# moy_precision-ne: 0.7644334975369457
# -------------------------------------------------
# AUC : [0.83306452 0.78056426 0.84285714 0.84677419 0.84294872]
# moy_AUC:  0.8292417667612328
# -------------------------------------------------
# VN : [19 24 20 25 17]
# VP : [20 17 21 16 20]
# FP : [1 5 1 6 9]
# FN : [11  5  9  4  4]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Ovins', 'Min_IRM', 'Var_IRM', 'Amp1_TempJ', 'VarT_bi_TempJ',
#        'Amp3_TempN', 'Max_TempN', 'VarT_ann_NDVI', 'Var_EVI', 'ProfAbs_Sub',
#        'Sol_Sable', 'Geom_maj', 'IR_Moy', 'Prec_Juill', 'Rad_Mai', 'Tmax_Fev',
#        'Tmax_Avril', 'Vent_Aout'],
#       dtype='object')
# nombre des variables 18
# Accuracy: [0.8627451  0.80392157 0.78431373 0.78431373 0.72      ]
# moy_accuracy: 0.7910588235294117
# -------------------------------------------------
# sensibilité : [0.80645161 0.77272727 0.7        0.8        0.79166667]
# moy_sensibilité:  0.774169110459433
# -------------------------------------------------
# spécificité : [0.95       0.82758621 0.9047619  0.77419355 0.65384615]
# moy_spécificité: 0.8220775627783414
# -------------------------------------------------
# MCC : [0.73878883 0.60031348 0.59815229 0.56339271 0.44839643]
# MCC:  0.5898087457388905
# -------------------------------------------------
# precision-po: [0.96153846 0.77272727 0.91304348 0.69565217 0.67857143]
# moy_precision-po: 0.8043065630022153
# -------------------------------------------------
# precision-ne : [0.76       0.82758621 0.67857143 0.85714286 0.77272727]
# moy_precision-ne: 0.7792055530676221
# -------------------------------------------------
# AUC : [0.84919355 0.78056426 0.83650794 0.82580645 0.85416667]
# moy_AUC:  0.8292477732994975
# -------------------------------------------------
# VN : [19 24 19 24 17]
# VP : [25 17 21 16 19]
# FP : [1 5 2 7 9]
# FN : [6 5 9 4 5]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Ovins', 'Min_IRM', 'Var_IRM', 'Amp1_TempJ', 'VarT_bi_TempJ',
#        'Amp3_TempN', 'Max_TempN', 'Var_EVI', 'ProfAbs_Sub', 'Sol_Sable',
#        'Geom_maj', 'IR_Moy', 'Prec_Juill', 'Rad_Mai', 'Tmax_Fev', 'Tmax_Avril',
#        'Vent_Aout'],
#       dtype='object')
# nombre des variables 17
# Accuracy: [0.80392157 0.76470588 0.80392157 0.82352941 0.74      ]
# moy_accuracy: 0.7872156862745099
# -------------------------------------------------
# sensibilité : [0.70967742 0.77272727 0.7        0.85       0.79166667]
# moy_sensibilité:  0.7648142717497557
# -------------------------------------------------
# spécificité : [0.95       0.75862069 0.95238095 0.80645161 0.69230769]
# moy_spécificité: 0.8319521894494086
# -------------------------------------------------
# MCC : [0.64726859 0.52723211 0.64827789 0.64410346 0.48514197]
# MCC:  0.5904048031347131
# -------------------------------------------------
# precision-po: [0.95652174 0.70833333 0.95454545 0.73913043 0.7037037 ]
# moy_precision-po: 0.8124469330991069
# -------------------------------------------------
# precision-ne : [0.67857143 0.81481481 0.68965517 0.89285714 0.7826087 ]
# moy_precision-ne: 0.7717014508618706
# -------------------------------------------------
# AUC : [0.82096774 0.79623824 0.85714286 0.8516129  0.83814103]
# moy_AUC:  0.8328205544918559
# -------------------------------------------------
# VN : [19 22 20 25 18]
# VP : [22 17 21 17 19]
# FP : [1 7 1 6 8]
# FN : [9 5 9 3 5]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Ovins', 'Min_IRM', 'Var_IRM', 'Amp1_TempJ', 'VarT_bi_TempJ',
#        'Amp3_TempN', 'Max_TempN', 'VarT_ann_NDVI', 'Var_EVI', 'ProfAbs_Sub',
#        'Sol_Sable', 'Geom_maj', 'IR_Moy', 'Prec_Juill', 'Rad_Mai', 'Rad_Oct',
#        'Tmax_Fev', 'Tmax_Avril', 'Vent_Aout'],
#       dtype='object')
# nombre des variables 19
# Accuracy: [0.80392157 0.84313725 0.78431373 0.78431373 0.76      ]
# moy_accuracy: 0.7951372549019607
# -------------------------------------------------
# sensibilité : [0.74193548 0.77272727 0.73333333 0.85       0.875     ]
# moy_sensibilité:  0.7945992179863148
# -------------------------------------------------
# spécificité : [0.9        0.89655172 0.85714286 0.74193548 0.65384615]
# moy_spécificité: 0.809895243799582
# -------------------------------------------------
# MCC : [0.6269466  0.67892483 0.58132097 0.57811407 0.53931937]
# MCC:  0.6009251669853655
# -------------------------------------------------
# precision-po: [0.92 0.85 0.88 0.68 0.7 ]
# moy_precision-po: 0.806
# -------------------------------------------------
# precision-ne : [0.69230769 0.83870968 0.69230769 0.88461538 0.85      ]
# moy_precision-ne: 0.7915880893300248
# -------------------------------------------------
# AUC : [0.82822581 0.78683386 0.83015873 0.83548387 0.84455128]
# moy_AUC:  0.8250507090857481
# -------------------------------------------------
# VN : [18 26 18 23 17]
# VP : [23 17 22 17 21]
# FP : [2 3 3 8 9]
# FN : [8 5 8 3 3]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Min_IRM', 'Var_IRM', 'Amp1_TempJ', 'VarT_bi_TempJ', 'Amp3_TempN',
#        'Max_TempN', 'VarT_ann_NDVI', 'Var_EVI', 'ProfAbs_Sub', 'Sol_Sable',
#        'Geom_maj', 'IR_Moy', 'Prec_Juill', 'Rad_Mars', 'Rad_Mai', 'Tmax_Fev',
#        'Tmax_Avril', 'Vent_Aout'],
#       dtype='object')
# nombre des variables 18
# Accuracy: [0.82352941 0.82352941 0.78431373 0.76470588 0.74      ]
# moy_accuracy: 0.7872156862745097
# -------------------------------------------------
# sensibilité : [0.77419355 0.77272727 0.66666667 0.75       0.875     ]
# moy_sensibilité:  0.7677174975562072
# -------------------------------------------------
# spécificité : [0.9        0.86206897 0.95238095 0.77419355 0.61538462]
# moy_spécificité: 0.8208056163339812
# -------------------------------------------------
# MCC : [0.65845145 0.63881398 0.61904762 0.51674606 0.50474437]
# MCC:  0.587560695994102
# -------------------------------------------------
# precision-po: [0.92307692 0.80952381 0.95238095 0.68181818 0.67741935]
# moy_precision-po: 0.8088438443277154
# -------------------------------------------------
# precision-ne : [0.72       0.83333333 0.66666667 0.82758621 0.84210526]
# moy_precision-ne: 0.7779382940108892
# -------------------------------------------------
# AUC : [0.83790323 0.77899687 0.83809524 0.83548387 0.80769231]
# moy_AUC:  0.8196343015531002
# -------------------------------------------------
# VN : [18 25 20 24 16]
# VP : [24 17 20 15 21]
# FP : [ 2  4  1  7 10]
# FN : [ 7  5 10  5  3]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Min_IRM', 'Var_IRM', 'Amp1_TempJ', 'VarT_bi_TempJ', 'Amp3_TempN',
#        'Max_TempN', 'VarT_ann_NDVI', 'Var_EVI', 'ProfAbs_Sub', 'Sol_Sable',
#        'Geom_maj', 'IR_Moy', 'Prec_Juill', 'Rad_Mai', 'Tmax_Avril',
#        'Vent_Aout'],
#       dtype='object')
# nombre des variables 16
# Accuracy: [0.76470588 0.78431373 0.78431373 0.76470588 0.86      ]
# moy_accuracy: 0.7916078431372549
# -------------------------------------------------
# sensibilité : [0.70967742 0.77272727 0.66666667 0.75       0.875     ]
# moy_sensibilité:  0.7548142717497556
# -------------------------------------------------
# spécificité : [0.85       0.79310345 0.95238095 0.77419355 0.84615385]
# moy_spécificité: 0.8431663590395514
# -------------------------------------------------
# MCC : [0.54660922 0.5631887  0.61904762 0.51674606 0.72057669]
# MCC:  0.5932336577010032
# -------------------------------------------------
# precision-po: [0.88       0.73913043 0.95238095 0.68181818 0.84      ]
# moy_precision-po: 0.8186659137963485
# -------------------------------------------------
# precision-ne : [0.65384615 0.82142857 0.66666667 0.82758621 0.88      ]
# moy_precision-ne: 0.7699055197675887
# -------------------------------------------------
# AUC : [0.80403226 0.76802508 0.83333333 0.81935484 0.85737179]
# moy_AUC:  0.8164234606698455
# -------------------------------------------------
# VN : [17 23 20 24 22]
# VP : [22 17 20 15 21]
# FP : [3 6 1 7 4]
# FN : [ 9  5 10  5  3]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Min_IRM', 'Var_IRM', 'Amp1_TempJ', 'VarT_bi_TempJ', 'Amp3_TempN',
#        'Max_TempN', 'VarT_ann_NDVI', 'Var_EVI', 'ProfAbs_Sub', 'Sol_Sable',
#        'IR_Moy', 'RV_Min', 'Prec_Juill', 'Rad_Mai', 'Tmax_Fev', 'Tmax_Avril',
#        'Vent_Aout'],
#       dtype='object')
# nombre des variables 17
# Accuracy: [0.78431373 0.78431373 0.82352941 0.80392157 0.74      ]
# moy_accuracy: 0.7872156862745099
# -------------------------------------------------
# sensibilité : [0.70967742 0.72727273 0.73333333 0.8        0.83333333]
# moy_sensibilité:  0.7607233626588467
# -------------------------------------------------
# spécificité : [0.9        0.82758621 0.95238095 0.80645161 0.65384615]
# moy_spécificité: 0.8280529852053767
# -------------------------------------------------
# MCC : [0.59635993 0.55837073 0.67821992 0.59783545 0.49314274]
# MCC:  0.584785752037406
# -------------------------------------------------
# precision-po: [0.91666667 0.76190476 0.95652174 0.72727273 0.68965517]
# moy_precision-po: 0.8104042134776769
# -------------------------------------------------
# precision-ne : [0.66666667 0.8        0.71428571 0.86206897 0.80952381]
# moy_precision-ne: 0.7705090311986863
# -------------------------------------------------
# AUC : [0.80403226 0.78213166 0.84285714 0.82258065 0.81730769]
# moy_AUC:  0.8137818799665297
# -------------------------------------------------
# VN : [18 24 20 25 17]
# VP : [22 16 22 16 20]
# FP : [2 5 1 6 9]
# FN : [9 6 8 4 4]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Min_IRM', 'Var_IRM', 'Amp1_TempJ', 'VarT_bi_TempJ', 'Amp3_TempN',
#        'Max_TempN', 'VarT_ann_NDVI', 'Var_EVI', 'Substratum', 'ProfAbs_Sub',
#        'Sol_Sable', 'IR_Moy', 'RV_Min', 'Prec_Juill', 'Rad_Mai', 'Tmax_Fev',
#        'Tmax_Avril', 'Vent_Aout'],
#       dtype='object')
# nombre des variables 18
# Accuracy: [0.82352941 0.7254902  0.80392157 0.80392157 0.78      ]
# moy_accuracy: 0.7873725490196077
# -------------------------------------------------
# sensibilité : [0.77419355 0.72727273 0.66666667 0.8        0.83333333]
# moy_sensibilité:  0.7602932551319648
# -------------------------------------------------
# spécificité : [0.9        0.72413793 1.         0.80645161 0.73076923]
# moy_spécificité: 0.8322717549413878
# -------------------------------------------------
# MCC : [0.65845145 0.44791401 0.67202151 0.59783545 0.56546349]
# MCC:  0.5883371798059123
# -------------------------------------------------
# precision-po: [0.92307692 0.66666667 1.         0.72727273 0.74074074]
# moy_precision-po: 0.8115514115514115
# -------------------------------------------------
# precision-ne : [0.72       0.77777778 0.67741935 0.86206897 0.82608696]
# moy_precision-ne: 0.7726706109310936
# -------------------------------------------------
# AUC : [0.82903226 0.7523511  0.84761905 0.84193548 0.84134615]
# moy_AUC:  0.8224568081158738
# -------------------------------------------------
# VN : [18 21 21 25 19]
# VP : [24 16 20 16 20]
# FP : [2 8 0 6 7]
# FN : [ 7  6 10  4  4]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Min_IRM', 'Var_IRM', 'Amp1_TempJ', 'VarT_bi_TempJ', 'Amp3_TempN',
#        'Max_TempN', 'VarT_ann_NDVI', 'Var_EVI', 'Substratum', 'ProfAbs_Sub',
#        'Sol_Sable', 'Rugosite_Min', 'IR_Moy', 'RV_Min', 'Prec_Juill',
#        'Rad_Mai', 'Tmax_Fev', 'Tmax_Avril', 'Vent_Aout'],
#       dtype='object')
# nombre des variables 19
# Accuracy: [0.82352941 0.7254902  0.82352941 0.82352941 0.76      ]
# moy_accuracy: 0.7912156862745097
# -------------------------------------------------
# sensibilité : [0.77419355 0.72727273 0.7        0.85       0.79166667]
# moy_sensibilité:  0.7686265884652981
# -------------------------------------------------
# spécificité : [0.9        0.72413793 1.         0.80645161 0.73076923]
# moy_spécificité: 0.8322717549413878
# -------------------------------------------------
# MCC : [0.65845145 0.44791401 0.7        0.64410346 0.5224359 ]
# MCC:  0.5945809629492173
# -------------------------------------------------
# precision-po: [0.92307692 0.66666667 1.         0.73913043 0.73076923]
# moy_precision-po: 0.811928651059086
# -------------------------------------------------
# precision-ne : [0.72       0.77777778 0.7        0.89285714 0.79166667]
# moy_precision-ne: 0.7764603174603174
# -------------------------------------------------
# AUC : [0.82419355 0.76332288 0.84920635 0.8483871  0.82852564]
# moy_AUC:  0.822727103881164
# -------------------------------------------------
# VN : [18 21 21 25 19]
# VP : [24 16 21 17 19]
# FP : [2 8 0 6 7]
# FN : [7 6 9 3 5]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Min_IRM', 'Var_IRM', 'Amp1_TempJ', 'VarT_bi_TempJ', 'Amp3_TempN',
#        'Max_TempN', 'VarT_ann_NDVI', 'Var_EVI', 'ProfAbs_Sub', 'Sol_Sable',
#        'Rugosite_Moy', 'IR_Moy', 'RV_Min', 'Prec_Juill', 'Rad_Mai', 'Tmax_Fev',
#        'Tmax_Avril', 'Vent_Aout'],
#       dtype='object')
# nombre des variables 18
# Accuracy: [0.82352941 0.78431373 0.76470588 0.80392157 0.76      ]
# moy_accuracy: 0.7872941176470588
# -------------------------------------------------
# sensibilité : [0.77419355 0.77272727 0.63333333 0.8        0.83333333]
# moy_sensibilité:  0.7627174975562073
# -------------------------------------------------
# spécificité : [0.9        0.79310345 0.95238095 0.80645161 0.69230769]
# moy_spécificité: 0.8288487411735466
# -------------------------------------------------
# MCC : [0.65845145 0.5631887  0.59041889 0.59783545 0.52904327]
# MCC:  0.5877875507542092
# -------------------------------------------------
# precision-po: [0.92307692 0.73913043 0.95       0.72727273 0.71428571]
# moy_precision-po: 0.8107531598835948
# -------------------------------------------------
# precision-ne : [0.72       0.82142857 0.64516129 0.86206897 0.81818182]
# moy_precision-ne: 0.7733681290900423
# -------------------------------------------------
# AUC : [0.825      0.78213166 0.82857143 0.84193548 0.82051282]
# moy_AUC:  0.8196302788794446
# -------------------------------------------------
# VN : [18 23 20 25 18]
# VP : [24 17 19 16 20]
# FP : [2 6 1 6 8]
# FN : [ 7  5 11  4  4]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Min_IRM', 'Var_IRM', 'Amp1_TempJ', 'VarT_bi_TempJ', 'Amp3_TempN',
#        'Max_TempN', 'VarT_ann_NDVI', 'Var_EVI', 'ProfAbs_Sub', 'Sol_Sable',
#        'Rugosite_Moy', 'RV_Min', 'Prec_Juill', 'Rad_Mai', 'Tmax_Fev',
#        'Tmax_Avril', 'Vent_Aout'],
#       dtype='object')
# nombre des variables 17
# Accuracy: [0.76470588 0.82352941 0.78431373 0.80392157 0.78      ]
# moy_accuracy: 0.7912941176470589
# -------------------------------------------------
# sensibilité : [0.67741935 0.77272727 0.7        0.8        0.875     ]
# moy_sensibilité:  0.7650293255131965
# -------------------------------------------------
# spécificité : [0.9        0.86206897 0.9047619  0.80645161 0.69230769]
# moy_spécificité: 0.8331180350980129
# -------------------------------------------------
# MCC : [0.56655783 0.63881398 0.59815229 0.59783545 0.57425174]
# MCC:  0.5951222565306615
# -------------------------------------------------
# precision-po: [0.91304348 0.80952381 0.91304348 0.72727273 0.72413793]
# moy_precision-po: 0.8174042848705518
# -------------------------------------------------
# precision-ne : [0.64285714 0.83333333 0.67857143 0.86206897 0.85714286]
# moy_precision-ne: 0.7747947454844006
# -------------------------------------------------
# AUC : [0.80322581 0.78213166 0.83809524 0.81935484 0.82051282]
# moy_AUC:  0.8126640730422711
# -------------------------------------------------
# VN : [18 25 19 25 18]
# VP : [21 17 21 16 21]
# FP : [2 4 2 6 8]
# FN : [10  5  9  4  3]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Min_IRM', 'Var_IRM', 'Amp1_TempJ', 'VarT_bi_TempJ', 'Amp3_TempN',
#        'Max_TempN', 'VarT_ann_NDVI', 'Var_EVI', 'ProfAbs_Sub', 'Sol_Sable',
#        'IR_Moy', 'IR_sd', 'RV_Min', 'Prec_Juill', 'Rad_Mai', 'Tmax_Fev',
#        'Tmax_Avril', 'Vent_Aout'],
#       dtype='object')
# nombre des variables 18
# Accuracy: [0.82352941 0.7254902  0.84313725 0.78431373 0.76      ]
# moy_accuracy: 0.7872941176470588
# -------------------------------------------------
# sensibilité : [0.77419355 0.72727273 0.73333333 0.8        0.83333333]
# moy_sensibilité:  0.7736265884652982
# -------------------------------------------------
# spécificité : [0.9        0.72413793 1.         0.77419355 0.69230769]
# ...
# les variables :
# Index(['Coniferes', 'VegInond', 'Min_IRM', 'Var_IRM', 'Moy_TempJ',
#        'Amp1_TempJ', 'Amp3_TempN', 'Max_TempN', 'ProfAbs_Sub', 'IPT_Med',
#        'IR_Moy', 'Prec_Janv', 'Prec_Juill', 'Rad_Mai', 'Tmax_Avril',
#        'Tmin_Janv', 'Vent_Aout', 'Vent_Sept'],
#       dtype='object')
# nombre des variables 18
# Accuracy: [0.84313725 0.80392157 0.74509804 0.76470588 0.86      ]
# moy_accuracy: 0.8033725490196078
# -------------------------------------------------
# sensibilité : [0.74193548 0.72727273 0.63333333 0.8        0.75      ]
# moy_sensibilité:  0.7305083088954056
# -------------------------------------------------
# spécificité : [1.         0.86206897 0.9047619  0.74193548 0.96153846]
# moy_spécificité: 0.8940609631377152
# -------------------------------------------------
# MCC : [0.72797934 0.59783545 0.53809524 0.53009771 0.73237419]
# MCC:  0.6252763838736712
# -------------------------------------------------
# precision-po: [1.         0.8        0.9047619  0.66666667 0.94736842]
# moy_precision-po: 0.8637593984962406
# -------------------------------------------------
# precision-ne : [0.71428571 0.80645161 0.63333333 0.85185185 0.80645161]
# moy_precision-ne: 0.7624748250554703
# -------------------------------------------------
# AUC : [0.87177419 0.79075235 0.83333333 0.83064516 0.86538462]
# moy_AUC:  0.8383779309307673
# -------------------------------------------------
# VN : [20 25 19 23 25]
# VP : [23 16 19 16 18]
# FP : [0 4 2 8 1]
# FN : [ 8  6 11  4  6]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Coniferes', 'VegInond', 'Min_IRM', 'Moy_TempJ', 'Amp1_TempJ',
#        'Amp3_TempN', 'Max_TempN', 'ProfAbs_Sub', 'IPT_Med', 'IR_Moy',
#        'Prec_Janv', 'Prec_Juill', 'Rad_Mai', 'Tmax_Avril', 'Tmin_Janv',
#        'Vent_Aout', 'Vent_Sept'],
#       dtype='object')
# nombre des variables 17
# Accuracy: [0.82352941 0.80392157 0.76470588 0.78431373 0.86      ]
# moy_accuracy: 0.8072941176470587
# -------------------------------------------------
# sensibilité : [0.70967742 0.77272727 0.66666667 0.8        0.79166667]
# moy_sensibilité:  0.748147605083089
# -------------------------------------------------
# spécificité : [1.         0.82758621 0.9047619  0.77419355 0.92307692]
# moy_spécificité: 0.8859237166244952
# -------------------------------------------------
# MCC : [0.69959467 0.60031348 0.56783465 0.56339271 0.72349231]
# MCC:  0.6309255615665655
# -------------------------------------------------
# precision-po: [1.         0.77272727 0.90909091 0.69565217 0.9047619 ]
# moy_precision-po: 0.8564464520986259
# -------------------------------------------------
# precision-ne : [0.68965517 0.82758621 0.65517241 0.85714286 0.82758621]
# moy_precision-ne: 0.7714285714285715
# -------------------------------------------------
# AUC : [0.84435484 0.79153605 0.83968254 0.82580645 0.87980769]
# moy_AUC:  0.8362375144939105
# -------------------------------------------------
# VN : [20 24 19 24 24]
# VP : [22 17 20 16 19]
# FP : [0 5 2 7 2]
# FN : [ 9  5 10  4  5]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['VegInond', 'Min_IRM', 'Moy_TempJ', 'Amp1_TempJ', 'Amp3_TempN',
#        'Max_TempN', 'ProfAbs_Sub', 'IPT_Med', 'IR_Moy', 'Prec_Janv',
#        'Prec_Juill', 'Rad_Mai', 'Tmax_Avril', 'Tmin_Janv', 'Vent_Aout',
#        'Vent_Sept'],
#       dtype='object')
# nombre des variables 16
# Accuracy: [0.80392157 0.80392157 0.78431373 0.78431373 0.88      ]
# moy_accuracy: 0.8112941176470588
# -------------------------------------------------
# sensibilité : [0.70967742 0.77272727 0.7        0.8        0.79166667]
# moy_sensibilité:  0.7548142717497556
# -------------------------------------------------
# spécificité : [0.95       0.82758621 0.9047619  0.77419355 0.96153846]
# moy_spécificité: 0.883616024316803
# -------------------------------------------------
# MCC : [0.64726859 0.60031348 0.59815229 0.56339271 0.76812153]
# MCC:  0.6354497172862725
# -------------------------------------------------
# precision-po: [0.95652174 0.77272727 0.91304348 0.69565217 0.95      ]
# moy_precision-po: 0.8575889328063241
# -------------------------------------------------
# precision-ne : [0.67857143 0.82758621 0.67857143 0.85714286 0.83333333]
# moy_precision-ne: 0.77504105090312
# -------------------------------------------------
# AUC : [0.8766129  0.80407524 0.84126984 0.86451613 0.89903846]
# moy_AUC:  0.857102514035217
# -------------------------------------------------
# VN : [19 24 19 24 25]
# VP : [22 17 21 16 19]
# FP : [1 5 2 7 1]
# FN : [9 5 9 4 5]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Coniferes', 'VegInond', 'Min_IRM', 'Moy_TempJ', 'Amp1_TempJ',
#        'Amp3_TempN', 'Max_TempN', 'VarT_bi_NDVI', 'ProfAbs_Sub', 'IPT_Med',
#        'IR_Moy', 'Prec_Janv', 'Prec_Juill', 'Rad_Mai', 'Tmax_Avril',
#        'Tmin_Janv', 'Vent_Aout', 'Vent_Sept'],
#       dtype='object')
# nombre des variables 18
# Accuracy: [0.80392157 0.80392157 0.80392157 0.80392157 0.84      ]
# moy_accuracy: 0.8111372549019608
# -------------------------------------------------
# sensibilité : [0.70967742 0.77272727 0.7        0.85       0.75      ]
# moy_sensibilité:  0.7564809384164224
# -------------------------------------------------
# spécificité : [0.95       0.82758621 0.95238095 0.77419355 0.92307692]
# moy_spécificité: 0.8854475261483049
# -------------------------------------------------
# MCC : [0.64726859 0.60031348 0.64827789 0.61055897 0.68640647]
# MCC:  0.6385650793709464
# -------------------------------------------------
# precision-po: [0.95652174 0.77272727 0.95454545 0.70833333 0.9       ]
# moy_precision-po: 0.8584255599472991
# -------------------------------------------------
# precision-ne : [0.67857143 0.82758621 0.68965517 0.88888889 0.8       ]
# moy_precision-ne: 0.7769403393541324
# -------------------------------------------------
# AUC : [0.85887097 0.81426332 0.85079365 0.82096774 0.875     ]
# moy_AUC:  0.8439791366710165
# -------------------------------------------------
# VN : [19 24 20 24 24]
# VP : [22 17 21 17 18]
# FP : [1 5 1 7 2]
# FN : [9 5 9 3 6]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Coniferes', 'VegInond', 'Min_IRM', 'Var_IRM', 'Moy_TempJ',
#        'Amp1_TempJ', 'Ph2_TempJ', 'Amp3_TempN', 'Max_TempN', 'ProfAbs_Sub',
#        'IPT_Med', 'IR_Moy', 'Prec_Janv', 'Prec_Juill', 'Rad_Mai', 'Tmax_Avril',
#        'Tmin_Janv', 'Vent_Aout', 'Vent_Sept'],
#       dtype='object')
# nombre des variables 19
# Accuracy: [0.78431373 0.84313725 0.80392157 0.82352941 0.8       ]
# moy_accuracy: 0.8109803921568627
# -------------------------------------------------
# sensibilité : [0.67741935 0.81818182 0.73333333 0.85       0.75      ]
# moy_sensibilité:  0.7657869012707723
# -------------------------------------------------
# spécificité : [0.95       0.86206897 0.9047619  0.80645161 0.84615385]
# moy_spécificité: 0.8738872658672434
# -------------------------------------------------
# MCC : [0.61850529 0.68025078 0.62917039 0.64410346 0.60001249]
# MCC:  0.6344084814021891
# -------------------------------------------------
# precision-po: [0.95454545 0.81818182 0.91666667 0.73913043 0.81818182]
# moy_precision-po: 0.8493412384716732
# -------------------------------------------------
# precision-ne : [0.65517241 0.86206897 0.7037037  0.89285714 0.78571429]
# moy_precision-ne: 0.7799033023170954
# -------------------------------------------------
# AUC : [0.85887097 0.82680251 0.86031746 0.82419355 0.86538462]
# moy_AUC:  0.8471138199336197
# -------------------------------------------------
# VN : [19 25 19 25 22]
# VP : [21 18 22 17 18]
# FP : [1 4 2 6 4]
# FN : [10  4  8  3  6]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Coniferes', 'VegInond', 'Min_IRM', 'Var_IRM', 'Moy_TempJ',
#        'Amp1_TempJ', 'Amp3_TempN', 'Max_TempN', 'ProfAbs_Sub', 'Geom_maj',
#        'IPT_Med', 'IR_Moy', 'Prec_Janv', 'Prec_Juill', 'Rad_Mai', 'Tmax_Avril',
#        'Tmin_Janv', 'Vent_Aout', 'Vent_Sept'],
#       dtype='object')
# nombre des variables 19
# Accuracy: [0.78431373 0.80392157 0.76470588 0.80392157 0.88      ]
# moy_accuracy: 0.8073725490196079
# -------------------------------------------------
# sensibilité : [0.64516129 0.77272727 0.66666667 0.85       0.79166667]
# moy_sensibilité:  0.7452443792766373
# -------------------------------------------------
# spécificité : [1.         0.82758621 0.9047619  0.77419355 0.96153846]
# moy_spécificité: 0.8936160243168029
# -------------------------------------------------
# MCC : [0.64516129 0.60031348 0.56783465 0.61055897 0.76812153]
# MCC:  0.6383979832886376
# -------------------------------------------------
# precision-po: [1.         0.77272727 0.90909091 0.70833333 0.95      ]
# moy_precision-po: 0.8680303030303029
# -------------------------------------------------
# precision-ne : [0.64516129 0.82758621 0.65517241 0.88888889 0.83333333]
# moy_precision-ne: 0.7700284266468916
# -------------------------------------------------
# AUC : [0.85725806 0.81583072 0.85555556 0.81935484 0.8974359 ]
# moy_AUC:  0.8490870154440788
# -------------------------------------------------
# VN : [20 24 19 24 25]
# VP : [20 17 20 17 19]
# FP : [0 5 2 7 1]
# FN : [11  5 10  3  5]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Coniferes', 'VegInond', 'Min_IRM', 'Var_IRM', 'Moy_TempJ',
#        'Amp1_TempJ', 'Amp3_TempN', 'Max_TempN', 'ProfAbs_Sub', 'Pente_sd',
#        'IPT_Med', 'IR_Moy', 'Prec_Janv', 'Prec_Juill', 'Rad_Mai', 'Tmax_Avril',
#        'Tmin_Janv', 'Vent_Aout', 'Vent_Sept'],
#       dtype='object')
# nombre des variables 19
# Accuracy: [0.78431373 0.80392157 0.76470588 0.78431373 0.88      ]
# moy_accuracy: 0.8034509803921569
# -------------------------------------------------
# sensibilité : [0.67741935 0.77272727 0.63333333 0.8        0.79166667]
# moy_sensibilité:  0.7350293255131966
# -------------------------------------------------
# spécificité : [0.95       0.82758621 0.95238095 0.77419355 0.96153846]
# moy_spécificité: 0.8931398338406126
# -------------------------------------------------
# MCC : [0.61850529 0.60031348 0.59041889 0.56339271 0.76812153]
# MCC:  0.6281503792382013
# -------------------------------------------------
# precision-po: [0.95454545 0.77272727 0.95       0.69565217 0.95      ]
# moy_precision-po: 0.8645849802371541
# -------------------------------------------------
# precision-ne : [0.65517241 0.82758621 0.64516129 0.85714286 0.83333333]
# moy_precision-ne: 0.7636792202976853
# -------------------------------------------------
# AUC : [0.84274194 0.81739812 0.85714286 0.82580645 0.89102564]
# moy_AUC:  0.846823000877506
# -------------------------------------------------
# VN : [19 24 20 24 25]
# VP : [21 17 19 16 19]
# FP : [1 5 1 7 1]
# FN : [10  5 11  4  5]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Coniferes', 'VegInond', 'Min_IRM', 'Var_IRM', 'Moy_TempJ',
#        'Amp1_TempJ', 'Amp3_TempN', 'Max_TempN', 'ProfAbs_Sub', 'IR_Moy',
#        'Prec_Janv', 'Prec_Juill', 'Prec_Sept', 'Rad_Mai', 'Tmax_Avril',
#        'Tmin_Janv', 'Vent_Aout', 'Vent_Sept'],
#       dtype='object')
# nombre des variables 18
# Accuracy: [0.82352941 0.80392157 0.76470588 0.78431373 0.84      ]
# moy_accuracy: 0.8032941176470588
# -------------------------------------------------
# sensibilité : [0.70967742 0.77272727 0.63333333 0.8        0.75      ]
# moy_sensibilité:  0.733147605083089
# -------------------------------------------------
# spécificité : [1.         0.82758621 0.95238095 0.77419355 0.92307692]
# moy_spécificité: 0.8954475261483049
# -------------------------------------------------
# MCC : [0.69959467 0.60031348 0.59041889 0.56339271 0.68640647]
# MCC:  0.6280252444293737
# -------------------------------------------------
# precision-po: [1.         0.77272727 0.95       0.69565217 0.9       ]
# moy_precision-po: 0.8636758893280632
# -------------------------------------------------
# precision-ne : [0.68965517 0.82758621 0.64516129 0.85714286 0.8       ]
# moy_precision-ne: 0.7639091053551565
# -------------------------------------------------
# AUC : [0.86209677 0.79858934 0.84285714 0.80806452 0.85576923]
# moy_AUC:  0.833475401128349
# -------------------------------------------------
# VN : [20 24 20 24 24]
# VP : [22 17 19 16 18]
# FP : [0 5 1 7 2]
# FN : [ 9  5 11  4  6]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Coniferes', 'Caduc', 'VegInond', 'Min_IRM', 'Var_IRM', 'Moy_TempJ',
#        'Amp1_TempJ', 'Amp3_TempN', 'Max_TempN', 'ProfAbs_Sub', 'IR_Moy',
#        'Prec_Janv', 'Prec_Juill', 'Prec_Sept', 'Rad_Mai', 'Tmax_Avril',
#        'Tmin_Janv', 'Vent_Aout', 'Vent_Sept'],
#       dtype='object')
# nombre des variables 19
# Accuracy: [0.80392157 0.80392157 0.78431373 0.76470588 0.88      ]
# moy_accuracy: 0.8073725490196079
# -------------------------------------------------
# sensibilité : [0.70967742 0.77272727 0.66666667 0.8        0.83333333]
# moy_sensibilité:  0.7564809384164224
# -------------------------------------------------
# spécificité : [0.95       0.82758621 0.95238095 0.74193548 0.92307692]
# moy_spécificité: 0.8789959132450791
# -------------------------------------------------
# MCC : [0.64726859 0.60031348 0.61904762 0.53009771 0.76130617]
# MCC:  0.6316067126066556
# -------------------------------------------------
# precision-po: [0.95652174 0.77272727 0.95238095 0.66666667 0.90909091]
# moy_precision-po: 0.8514775079992469
# -------------------------------------------------
# precision-ne : [0.67857143 0.82758621 0.66666667 0.85185185 0.85714286]
# moy_precision-ne: 0.7763638022258712
# -------------------------------------------------
# AUC : [0.83145161 0.77821317 0.83809524 0.82741935 0.875     ]
# moy_AUC:  0.8300358743962748
# -------------------------------------------------
# VN : [19 24 20 23 24]
# VP : [22 17 20 16 20]
# FP : [1 5 1 8 2]
# FN : [ 9  5 10  4  4]
# -----------------------------------------------------------------------
# -----------------------------------------------------------------------
# les variables :
# Index(['Coniferes', 'VegInond', 'Min_IRM', 'Var_IRM', 'Moy_TempJ',
#        'Amp1_TempJ', 'Amp3_TempN', 'Max_TempN', 'ProfAbs_Sub', 'IR_Moy',
#        'Prec_Janv', 'Prec_Juill', 'Rad_Mai', 'Tmax_Avril', 'Tmin_Janv',
#        'Tmin_Sept', 'Vent_Aout', 'Vent_Sept'],
#       dtype='object')
# nombre des variables 18
# Accuracy: [0.84313725 0.80392157 0.78431373 0.78431373 0.82      ]
# moy_accuracy: 0.8071372549019606
# -------------------------------------------------
# sensibilité : [0.74193548 0.77272727 0.7        0.85       0.79166667]
# moy_sensibilité:  0.7712658846529814
# -------------------------------------------------
# spécificité : [1.         0.82758621 0.9047619  0.74193548 0.84615385]
# moy_spécificité: 0.8640874883366539
# -------------------------------------------------
# MCC : [0.72797934 0.60031348 0.59815229 0.57811407 0.63935929]
# MCC:  0.6287836926004029
# -------------------------------------------------
# precision-po: [1.         0.77272727 0.91304348 0.68       0.82608696]
# moy_precision-po: 0.8383715415019763
# -------------------------------------------------
# precision-ne : [0.71428571 0.82758621 0.67857143 0.88461538 0.81481481]
# moy_precision-ne: 0.7839747098367789
# -------------------------------------------------
# AUC : [0.85403226 0.77507837 0.85238095 0.82580645 0.85737179]
# moy_AUC:  0.8329339653672246
# -------------------------------------------------
# VN : [20 24 19 23 22]
# VP : [23 17 21 17 19]
# FP : [0 5 2 8 4]
# FN : [8 5 9 3 5]
